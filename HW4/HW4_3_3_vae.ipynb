# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

learning_rate = 0.001
batch_size = 256
h = 128
z_size = 100
x_size = 784
x1_size = 10

#read data
mnist = input_data.read_data_sets('../../MNIST_data', one_hot=True)

def fullLayer(input_data, output_size, act, name, std = 0.1):
    w = tf.Variable(tf.random_normal([input_data.get_shape().as_list()[1], output_size], stddev = std, name = name + "_weigth"))
    b = tf.Variable(tf.zeros([output_size]), name = name + "_bias")
    return act(tf.matmul(input_data, w) + b)

x = tf.placeholder(tf.float32, [None, x_size], name='x')


with tf.variable_scope("encoder"):
    enc_hidden = fullLayer(x, h, act = tf.nn.relu ,name = "enc_hidden")
    enc_mu = fullLayer(enc_hidden, z_size, act = tf.identity , name = "enc_mu")
    enc_sigma = fullLayer(enc_hidden, z_size, act = tf.exp, name = "enc_sigma")
    
with tf.variable_scope("sampling"):
    eps = tf.Variable(tf.random_normal([z_size]))
    z = eps * enc_sigma + enc_mu

with tf.variable_scope("decoder"):
    dec_hidden = fullLayer(z, h, act = tf.nn.relu,name = "dec_hidden")
    dec_mu = fullLayer(dec_hidden, x_size, act = tf.nn.sigmoid, name = "dec_mu")
    dec_sigma = fullLayer(dec_hidden, x_size, act = tf.nn.sigmoid, name = "dec_sigma")

with tf.variable_scope("vae_loss"):
    ent_loss = -tf.reduce_sum(x * tf.log(1e-10 + dec_mu) + (1-x) * tf.log(1e-10 + 1 - dec_mu), axis = 1)
    kl_loss = -0.5 * tf.reduce_sum(1 + 2 * tf.log(enc_sigma) - tf.square(enc_mu) - enc_sigma * enc_sigma, axis = 1)
    print(ent_loss.shape)
    print(kl_loss.shape)
    loss = tf.reduce_mean(ent_loss + kl_loss)

with tf.variable_scope("optimizer_init"):
    optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)
    init = tf.global_variables_initializer()
# Out:
# Extracting ../../MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../../MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../../MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../../MNIST_data/t10k-labels-idx1-ubyte.gz
# (?,)
# (?,)

# %%
import time

n_epochs = 100

#just some config for not getting whole server
gpu_options = tf.GPUOptions(allow_growth=True)
config = tf.ConfigProto(gpu_options=gpu_options)

sess = tf.Session(config = config)
##starting time
start_time = time.time()
##initialize the variables
sess.run(init)

## number of training batches
n_batches = int(mnist.train.num_examples / batch_size)

for i in range(n_epochs):  # train the model n_epochs times
    total_loss = 0
    total_acc = 0
    for _ in range(n_batches):
        ##training batches
        x_batch, _ = mnist.train.next_batch(batch_size)
        _, loss_batch = sess.run([optimizer, loss], feed_dict={x: x_batch})
        total_loss += loss_batch

    print('epoch {}, Average loss : {}'.format(i, total_loss / n_batches))

print('Total time: {0} seconds'.format(time.time() - start_time))
print('Optimization Finished!')
# Out:
# epoch 0, Average loss : 214.51158441561404
# epoch 1, Average loss : 138.12789617520627
# epoch 2, Average loss : 127.21982627939956
# epoch 3, Average loss : 122.55990119292358
# epoch 4, Average loss : 119.29770089978369
# epoch 5, Average loss : 116.94518190900857
# epoch 6, Average loss : 115.19246520283066
# epoch 7, Average loss : 113.93639740988473
# epoch 8, Average loss : 112.69988008303064
# epoch 9, Average loss : 111.81983858625466
# epoch 10, Average loss : 111.05031204223633
# epoch 11, Average loss : 110.28471574159425
# epoch 12, Average loss : 109.55141937398464
# epoch 13, Average loss : 108.89553964917904
# epoch 14, Average loss : 108.35513893911772
# epoch 15, Average loss : 107.59270958588502
# epoch 16, Average loss : 107.20773679073726
# epoch 17, Average loss : 106.69194184062637
# epoch 18, Average loss : 106.23466074578116
# epoch 19, Average loss : 105.67447972520489
# epoch 20, Average loss : 105.29811688004253
# epoch 21, Average loss : 105.046061292987
# epoch 22, Average loss : 104.55350530036142
# epoch 23, Average loss : 104.20189773702175
# epoch 24, Average loss : 103.84435593079183
# epoch 25, Average loss : 103.76470822485808
# epoch 26, Average loss : 103.12348324784608
# epoch 27, Average loss : 103.0388755441826
# epoch 28, Average loss : 102.75838452633296
# epoch 29, Average loss : 102.63550378674658
# epoch 30, Average loss : 102.16561158795223
# epoch 31, Average loss : 102.03329221778941
# epoch 32, Average loss : 101.86425717077523
# epoch 33, Average loss : 101.64774803803346
# epoch 34, Average loss : 101.47589663924458
# epoch 35, Average loss : 101.35004870691031
# epoch 36, Average loss : 101.05167567172897
# epoch 37, Average loss : 100.94452221594125
# epoch 38, Average loss : 100.77785816370884
# epoch 39, Average loss : 100.65742403547341
# epoch 40, Average loss : 100.38526966415833
# epoch 41, Average loss : 100.28185692903037
# epoch 42, Average loss : 100.34994546052451
# epoch 43, Average loss : 99.9076036114559
# epoch 44, Average loss : 100.01847907093084
# epoch 45, Average loss : 99.80476710952331
# epoch 46, Average loss : 99.69926987407364
# epoch 47, Average loss : 99.4717957327299
# epoch 48, Average loss : 99.47717916185611
# epoch 49, Average loss : 99.4284224109115
# epoch 50, Average loss : 99.16083455308575
# epoch 51, Average loss : 99.19354968204676
# epoch 52, Average loss : 98.83817227087289
# epoch 53, Average loss : 99.09383392333984
# epoch 54, Average loss : 98.79422310802424
# epoch 55, Average loss : 98.76157871139384
# epoch 56, Average loss : 98.62425934265707
# epoch 57, Average loss : 98.43409319013078
# epoch 58, Average loss : 98.51657863866502
# epoch 59, Average loss : 98.5154216445495
# epoch 60, Average loss : 98.22755278827988
# epoch 61, Average loss : 98.2265697372294
# epoch 62, Average loss : 98.23257357160622
# epoch 63, Average loss : 97.97606694586923
# epoch 64, Average loss : 98.0648709591304
# epoch 65, Average loss : 97.69731450303692
# epoch 66, Average loss : 97.99116605241721
# epoch 67, Average loss : 97.72353527033441
# epoch 68, Average loss : 97.66276161692967
# epoch 69, Average loss : 97.75653104692977
# epoch 70, Average loss : 97.39458412099107
# epoch 71, Average loss : 97.60194714269906
# epoch 72, Average loss : 97.38041997178692
# epoch 73, Average loss : 97.45674133300781
# epoch 74, Average loss : 97.29801092415212
# epoch 75, Average loss : 97.31595789829147
# epoch 76, Average loss : 97.03589380567318
# epoch 77, Average loss : 97.09914098721798
# epoch 78, Average loss : 97.19503424100786
# epoch 79, Average loss : 96.89377258871204
# epoch 80, Average loss : 96.96929560866312
# epoch 81, Average loss : 97.00130148914373
# epoch 82, Average loss : 96.78772617946161
# epoch 83, Average loss : 96.75290462458246
# epoch 84, Average loss : 96.76655696262823
# epoch 85, Average loss : 96.75521016343731
# epoch 86, Average loss : 96.62190503271941
# epoch 87, Average loss : 96.55242666797103
# epoch 88, Average loss : 96.64353907219717
# epoch 89, Average loss : 96.52000309596552
# epoch 90, Average loss : 96.40805053710938
# epoch 91, Average loss : 96.2955549721406
# epoch 92, Average loss : 96.38428557921793
# epoch 93, Average loss : 96.288889697779
# epoch 94, Average loss : 96.37816627003322
# epoch 95, Average loss : 96.28246966923508
# epoch 96, Average loss : 96.24238832420278
# epoch 97, Average loss : 96.01031144757137
# epoch 98, Average loss : 96.04609844172113
# epoch 99, Average loss : 96.10086897377656
# Total time: 146.66256284713745 seconds
# Optimization Finished!

# %%
def to_one_hat(x):
    out = np.zeros((len(x), 10))
    for i, a in enumerate(x):
        out[i, a] = 1
    return out

# %%
import matplotlib.pyplot as plt
mean = np.zeros(z_size)
cov = np.eye(z_size)
z1 = np.random.multivariate_normal(mean, cov, 25)
d_mu, d_sigma = sess.run([dec_mu, dec_sigma],feed_dict={z:z1})

fig, axes = plt.subplots(5, 5, figsize = (10,10))
for i, im in enumerate(d_mu):
    axes[i // 5, i % 5].imshow(im.reshape(28,28))
plt.show()
