# %%
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import numpy as np
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

learning_rate = tf.Variable(0.0001)
batch_size = 256
hidden_size = 128
z_size = 100
x2_size = 784
x1_size = 10
dropout = 0.5
is_training = True
#read data
mnist = input_data.read_data_sets('../../MNIST_data', one_hot=True)

xavier_init = tf.contrib.layers.xavier_initializer()

def fullLayer(input_data, output_size, act, name):
    w = tf.Variable(xavier_init([input_data.get_shape().as_list()[1], output_size]), name = name + "_weigth")
    b = tf.Variable(tf.zeros([output_size]), name = name + "_bias")
    return act(tf.matmul(input_data, w) + b)

def leakyRelu(x, alpha = 0.1):
    return tf.nn.relu(x) - alpha * tf.nn.relu(-x)

x2 = tf.placeholder(tf.float32, [None, x2_size], name='x2')
x1 = tf.placeholder(tf.float32, [None, x1_size], name='x1')
z = tf.placeholder(tf.float32, [None, z_size], name='z')

with tf.variable_scope("generator"):
    w_gen_hidden = tf.Variable(xavier_init([z_size + x1_size, hidden_size]), name = "w_gen_hidden")
    b_gen_hidden = tf.Variable(tf.zeros([hidden_size]), name = "b_gen_hidden")
    
    w_gen_result = tf.Variable(xavier_init([hidden_size, x2_size]), name = "w_gen_result")
    b_gen_result = tf.Variable(tf.zeros([x2_size]), name = "b_gen_result")
    
    gen_hidden = leakyRelu(tf.matmul(tf.concat((z, x1), axis = 1), w_gen_hidden) + b_gen_hidden)
    gen_hidden_dropout = tf.layers.dropout(gen_hidden, rate=dropout, training=is_training)
    fake_x = tf.nn.sigmoid(tf.matmul(gen_hidden_dropout, w_gen_result) + b_gen_result)
    
    G_params = [w_gen_hidden, b_gen_hidden, w_gen_result, b_gen_result]


with tf.variable_scope("discriminator"):
    w_dis_hidden = tf.Variable(xavier_init([x2_size + x1_size, hidden_size]), name = "w_dis_hidden")
    b_dis_hidden = tf.Variable(tf.zeros([hidden_size]), name = "b_dis_hidden")
    
    w_result = tf.Variable(xavier_init([hidden_size, 1]), name = "w_dis_result")
    b_result = tf.Variable(tf.zeros([1]), name = "b_dis_result")
    
    dis_hidden_fake = leakyRelu(tf.matmul(tf.concat((fake_x,x1), axis = 1), w_dis_hidden) + b_dis_hidden)
    fake_result = tf.nn.sigmoid(tf.matmul(dis_hidden_fake , w_result) + b_result)
    
    dis_hidden_true = leakyRelu(tf.matmul(tf.concat((x2,x1), axis = 1), w_dis_hidden) + b_dis_hidden)
    true_result = tf.nn.sigmoid(tf.matmul(dis_hidden_true , w_result) + b_result)
    
    D_params = [w_dis_hidden, b_dis_hidden, w_result, b_result]
    

with tf.variable_scope("loss"):
    discriminator_loss = -tf.reduce_mean(tf.log(true_result+ 1e-20) + tf.log(1- fake_result + 1e-20))
    generator_loss = -tf.reduce_mean(tf.log(fake_result+ 1e-20))
    

with tf.variable_scope("optimizer_init"):
    discriminator_optimizer = tf.train.AdamOptimizer(learning_rate).minimize(discriminator_loss, var_list = D_params)
    generator_optimizer = tf.train.AdamOptimizer(learning_rate).minimize(generator_loss, var_list = G_params)
    init = tf.global_variables_initializer()
# Out:
# Extracting ../../MNIST_data/train-images-idx3-ubyte.gz
# Extracting ../../MNIST_data/train-labels-idx1-ubyte.gz
# Extracting ../../MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting ../../MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
print(1000000 / mnist.train.num_examples * 20)
# Out:
# 363.6363636363637

# %%
import time

n_epochs = 300
k = 1


#just some config for not getting whole server
gpu_options = tf.GPUOptions(allow_growth=True)
config = tf.ConfigProto(gpu_options=gpu_options)

sess = tf.Session(config = config)
##starting time
start_time = time.time()
##initialize the variables
sess.run(init)

## number of training batches
n_batches = int(mnist.train.num_examples / batch_size / (k+1))

for i in range(n_epochs):  # train the model n_epochs times
    total_generator_loss = 0
    total_discriminator_loss = 0
    for b in range(n_batches):
        
        ##training discriminator
        for j in range(k):
            z1 = np.random.normal(0, 1.0, [batch_size, z_size])
            
            x2_batch, x1_batch = mnist.train.next_batch(batch_size)
            _, loss_batch = sess.run([discriminator_optimizer, discriminator_loss], feed_dict={x1: x1_batch, x2: x2_batch, z:z1})
            total_discriminator_loss += loss_batch
            
        ##training generator
        mean = np.zeros(z_size)
        cov = np.eye(z_size)
        z1 = np.random.multivariate_normal(mean, cov, batch_size)
                                           
        x2_batch, x1_batch = mnist.train.next_batch(batch_size)
        _, loss_batch = sess.run([generator_optimizer, generator_loss], feed_dict={x1: x1_batch, x2: x2_batch, z:z1})
        total_generator_loss += loss_batch
        
    print('epoch {}, Average discriminator loss : {}, Average generator loss : {}'.format(i, total_discriminator_loss / k/n_batches, total_generator_loss / n_batches))
            
print('Total time: {0} seconds'.format(time.time() - start_time))
print('Optimization Finished!')
# Out:
# epoch 0, Average discriminator loss : 0.43792937514937924, Average generator loss : 2.9253370539050234
# epoch 1, Average discriminator loss : 0.4909826316566111, Average generator loss : 2.8299385409488855
# epoch 2, Average discriminator loss : 0.43553841309012653, Average generator loss : 2.9531683587582314
# epoch 3, Average discriminator loss : 0.37173235277149164, Average generator loss : 3.1630452592796257
# epoch 4, Average discriminator loss : 0.3626415868785894, Average generator loss : 3.1960224325411786
# epoch 5, Average discriminator loss : 0.36867624075613287, Average generator loss : 3.1069739176848223
# epoch 6, Average discriminator loss : 0.43315851939058747, Average generator loss : 2.9585963097688195
# epoch 7, Average discriminator loss : 0.5322633196260328, Average generator loss : 2.727861150402889
# epoch 8, Average discriminator loss : 0.39366659048561736, Average generator loss : 3.074758892861482
# epoch 9, Average discriminator loss : 0.3920270343807256, Average generator loss : 3.069978043297741
# epoch 10, Average discriminator loss : 0.37155773929346386, Average generator loss : 3.1782550187868495
# epoch 11, Average discriminator loss : 0.408681268168387, Average generator loss : 3.073048774327073
# epoch 12, Average discriminator loss : 0.4529323633586135, Average generator loss : 2.9036644975715706
# epoch 13, Average discriminator loss : 0.4531737752606936, Average generator loss : 2.886227741419712
# epoch 14, Average discriminator loss : 0.4394789073511819, Average generator loss : 2.9684790473118006
# epoch 15, Average discriminator loss : 0.4492815434932709, Average generator loss : 2.9429114310540885
# epoch 16, Average discriminator loss : 0.4452129204139531, Average generator loss : 2.933489278098133
# epoch 17, Average discriminator loss : 0.37924288784232096, Average generator loss : 3.1331024281332427
# epoch 18, Average discriminator loss : 0.4255091288936472, Average generator loss : 3.120318760381681
# epoch 19, Average discriminator loss : 0.4482404801333062, Average generator loss : 2.962141270949462
# epoch 20, Average discriminator loss : 0.3266655957308885, Average generator loss : 3.408195622613497
# epoch 21, Average discriminator loss : 0.3574222913969343, Average generator loss : 3.2761192410905786
# epoch 22, Average discriminator loss : 0.40358006369287724, Average generator loss : 3.117817473188739
# epoch 23, Average discriminator loss : 0.44209747977345903, Average generator loss : 2.978174122694497
# epoch 24, Average discriminator loss : 0.42071264954370874, Average generator loss : 3.0442606310978113
# epoch 25, Average discriminator loss : 0.5410673387139757, Average generator loss : 2.8230325707765385
# epoch 26, Average discriminator loss : 0.42111361918048323, Average generator loss : 3.0999421961953706
# epoch 27, Average discriminator loss : 0.35076214331332767, Average generator loss : 3.256873251121735
# epoch 28, Average discriminator loss : 0.32406379769895677, Average generator loss : 3.3790605424720552
# epoch 29, Average discriminator loss : 0.3788393663468762, Average generator loss : 3.2132508086266918
# epoch 30, Average discriminator loss : 0.3528597563783699, Average generator loss : 3.271370130164601
# epoch 31, Average discriminator loss : 0.3738893763484242, Average generator loss : 3.17206606018209
# epoch 32, Average discriminator loss : 0.43562533476642357, Average generator loss : 2.988506649142114
# epoch 33, Average discriminator loss : 0.4489038266311182, Average generator loss : 2.928760176507112
# epoch 34, Average discriminator loss : 0.5039738088010628, Average generator loss : 2.805956207703207
# epoch 35, Average discriminator loss : 0.48198583944935663, Average generator loss : 2.8356446328564227
# epoch 36, Average discriminator loss : 0.4516712087337102, Average generator loss : 2.9622997324043343
# epoch 37, Average discriminator loss : 0.4296011752057298, Average generator loss : 2.996534180418353
# epoch 38, Average discriminator loss : 0.4319665253719437, Average generator loss : 2.9828684441397124
# epoch 39, Average discriminator loss : 0.45270592197079523, Average generator loss : 2.8810619483484285
# epoch 40, Average discriminator loss : 0.5204198109769376, Average generator loss : 2.746844398641141
# epoch 41, Average discriminator loss : 0.46787159688004826, Average generator loss : 2.874969433401233
# epoch 42, Average discriminator loss : 0.40355278259125826, Average generator loss : 3.0399693529182503
# epoch 43, Average discriminator loss : 0.4306189384415885, Average generator loss : 2.9927144206572915
# epoch 44, Average discriminator loss : 0.46781096558704555, Average generator loss : 2.9072182624139518
# epoch 45, Average discriminator loss : 0.4594840619051568, Average generator loss : 2.8757562102558456
# epoch 46, Average discriminator loss : 0.4468186717724132, Average generator loss : 2.874116124393784
# epoch 47, Average discriminator loss : 0.4425665652640512, Average generator loss : 2.8777258819508775
# epoch 48, Average discriminator loss : 0.5086535794712673, Average generator loss : 2.754047349234608
# epoch 49, Average discriminator loss : 0.46493666222162333, Average generator loss : 2.898412642077865
# epoch 50, Average discriminator loss : 0.4399214949563285, Average generator loss : 2.9388804859090074
# epoch 51, Average discriminator loss : 0.471873743511806, Average generator loss : 2.852085813183651
# epoch 52, Average discriminator loss : 0.4621405570863563, Average generator loss : 2.881372977640027
# epoch 53, Average discriminator loss : 0.46846880533984886, Average generator loss : 2.877209177641111
# epoch 54, Average discriminator loss : 0.45007485736196284, Average generator loss : 2.887627265163671
# epoch 55, Average discriminator loss : 0.4803868434696554, Average generator loss : 2.7677100038974083
# epoch 56, Average discriminator loss : 0.49409941173045435, Average generator loss : 2.7828776814113154
# epoch 57, Average discriminator loss : 0.4474157409690251, Average generator loss : 2.9096495124781243
# epoch 58, Average discriminator loss : 0.4785527620360116, Average generator loss : 2.8064502800736473
# epoch 59, Average discriminator loss : 0.4958724942162772, Average generator loss : 2.789001048168289
# epoch 60, Average discriminator loss : 0.4668924245878915, Average generator loss : 2.826833163466409
# epoch 61, Average discriminator loss : 0.47985251846714555, Average generator loss : 2.7971405938406972
# epoch 62, Average discriminator loss : 0.4768452140215401, Average generator loss : 2.7944275419288704
# epoch 63, Average discriminator loss : 0.4771904903594579, Average generator loss : 2.8126199468273985
# epoch 64, Average discriminator loss : 0.49415669290818903, Average generator loss : 2.7805465805196317
# epoch 65, Average discriminator loss : 0.48568281726302387, Average generator loss : 2.781108769300942
# epoch 66, Average discriminator loss : 0.4960015806082253, Average generator loss : 2.7184102557529912
# epoch 67, Average discriminator loss : 0.4771859052582322, Average generator loss : 2.7668477129713396
# epoch 68, Average discriminator loss : 0.4881211839546667, Average generator loss : 2.7881700480095692
# epoch 69, Average discriminator loss : 0.5118470122323973, Average generator loss : 2.746252679379187
# epoch 70, Average discriminator loss : 0.4736741731099993, Average generator loss : 2.8283856182454903
# epoch 71, Average discriminator loss : 0.5072192741888706, Average generator loss : 2.7229903969809275
# epoch 72, Average discriminator loss : 0.5179679583166247, Average generator loss : 2.686285081310807
# epoch 73, Average discriminator loss : 0.49301237229988953, Average generator loss : 2.740517562794908
# epoch 74, Average discriminator loss : 0.4992427784148778, Average generator loss : 2.77260890408097
# epoch 75, Average discriminator loss : 0.5271158427278572, Average generator loss : 2.695645169677021
# epoch 76, Average discriminator loss : 0.48690852327881573, Average generator loss : 2.743841247023823
# epoch 77, Average discriminator loss : 0.5276900326537195, Average generator loss : 2.696320937058636
# epoch 78, Average discriminator loss : 0.5230612044579515, Average generator loss : 2.722044409992539
# epoch 79, Average discriminator loss : 0.509773542669332, Average generator loss : 2.7258446305711694
# epoch 80, Average discriminator loss : 0.49517562261251646, Average generator loss : 2.756271291001935
# epoch 81, Average discriminator loss : 0.5274902005618978, Average generator loss : 2.6257713041572925
# epoch 82, Average discriminator loss : 0.5257244569675945, Average generator loss : 2.634290131453042
# epoch 83, Average discriminator loss : 0.5172833780819011, Average generator loss : 2.701667161745446
# epoch 84, Average discriminator loss : 0.5081519941303217, Average generator loss : 2.721442349603243
# epoch 85, Average discriminator loss : 0.5299464982246684, Average generator loss : 2.647526186203288
# epoch 86, Average discriminator loss : 0.5229860878436365, Average generator loss : 2.6770108592844455
# epoch 87, Average discriminator loss : 0.5077596253880831, Average generator loss : 2.687828097388009
# epoch 88, Average discriminator loss : 0.533152392534452, Average generator loss : 2.6100808927946
# epoch 89, Average discriminator loss : 0.518059942209832, Average generator loss : 2.6510597634538313
# epoch 90, Average discriminator loss : 0.5081666201074547, Average generator loss : 2.6804334716262104
# epoch 91, Average discriminator loss : 0.5231106852259592, Average generator loss : 2.676834710290499
# epoch 92, Average discriminator loss : 0.5119386713638484, Average generator loss : 2.673916493620828
# epoch 93, Average discriminator loss : 0.537639999501059, Average generator loss : 2.6217562149618274
# epoch 94, Average discriminator loss : 0.5232585136578461, Average generator loss : 2.650687286786944
# epoch 95, Average discriminator loss : 0.5161263132206747, Average generator loss : 2.662954773858329
# epoch 96, Average discriminator loss : 0.5433964590045893, Average generator loss : 2.6360319150942506
# epoch 97, Average discriminator loss : 0.5242201287612737, Average generator loss : 2.634539441527607
# epoch 98, Average discriminator loss : 0.5293243733521934, Average generator loss : 2.616846334154361
# epoch 99, Average discriminator loss : 0.537212481844091, Average generator loss : 2.6020799151090817
# epoch 100, Average discriminator loss : 0.5173902347266117, Average generator loss : 2.640172789029986
# epoch 101, Average discriminator loss : 0.5321744557853058, Average generator loss : 2.6400619890088235
# epoch 102, Average discriminator loss : 0.5319416603752386, Average generator loss : 2.642072174036614
# epoch 103, Average discriminator loss : 0.538261044805295, Average generator loss : 2.5870738452840074
# epoch 104, Average discriminator loss : 0.5205382147682047, Average generator loss : 2.6310619171534744
# epoch 105, Average discriminator loss : 0.5282858153369939, Average generator loss : 2.616338556057939
# epoch 106, Average discriminator loss : 0.544846213866617, Average generator loss : 2.603368705678209
# epoch 107, Average discriminator loss : 0.5306913950175882, Average generator loss : 2.5963772568747263
# epoch 108, Average discriminator loss : 0.5361679469313577, Average generator loss : 2.6193338977956326
# epoch 109, Average discriminator loss : 0.5290963646964492, Average generator loss : 2.621973761888308
# epoch 110, Average discriminator loss : 0.5333196342548477, Average generator loss : 2.5927833352133494
# epoch 111, Average discriminator loss : 0.5283882069253476, Average generator loss : 2.6015615619231607
# epoch 112, Average discriminator loss : 0.5606532726332406, Average generator loss : 2.5138315463734564
# epoch 113, Average discriminator loss : 0.5025688459940045, Average generator loss : 2.6643845678489897
# epoch 114, Average discriminator loss : 0.5509960587336639, Average generator loss : 2.561267358120357
# epoch 115, Average discriminator loss : 0.5460536502232062, Average generator loss : 2.572807129298415
# epoch 116, Average discriminator loss : 0.5357366240470209, Average generator loss : 2.5767870796061008
# epoch 117, Average discriminator loss : 0.5222569667847357, Average generator loss : 2.577645778656006
# epoch 118, Average discriminator loss : 0.5506347055747131, Average generator loss : 2.542804270147163
# epoch 119, Average discriminator loss : 0.543086331581401, Average generator loss : 2.565246504043864
# epoch 120, Average discriminator loss : 0.5341572872946195, Average generator loss : 2.5628757565935083
# epoch 121, Average discriminator loss : 0.5420233011245728, Average generator loss : 2.573620426320584
# epoch 122, Average discriminator loss : 0.5555741948502086, Average generator loss : 2.5342538691012657
# epoch 123, Average discriminator loss : 0.5412984869190466, Average generator loss : 2.566526386225335
# epoch 124, Average discriminator loss : 0.5480640926093698, Average generator loss : 2.550224651800138
# epoch 125, Average discriminator loss : 0.526427351147215, Average generator loss : 2.585677068924235
# epoch 126, Average discriminator loss : 0.5578149142109345, Average generator loss : 2.4876800185052033
# epoch 127, Average discriminator loss : 0.5420709511387014, Average generator loss : 2.521485141504591
# epoch 128, Average discriminator loss : 0.5475320253416757, Average generator loss : 2.5016517616878047
# epoch 129, Average discriminator loss : 0.5417680083034194, Average generator loss : 2.5790419912783897
# epoch 130, Average discriminator loss : 0.5595966368635125, Average generator loss : 2.505731518023482
# epoch 131, Average discriminator loss : 0.5534635556635455, Average generator loss : 2.5189652086418364
# epoch 132, Average discriminator loss : 0.5509234939780191, Average generator loss : 2.4885876156459346
# epoch 133, Average discriminator loss : 0.5514541889462515, Average generator loss : 2.5420150645425386
# epoch 134, Average discriminator loss : 0.5396435711985437, Average generator loss : 2.565252595972792
# epoch 135, Average discriminator loss : 0.5724535553811867, Average generator loss : 2.5018864457852374
# epoch 136, Average discriminator loss : 0.5554676977830513, Average generator loss : 2.520710905021596
# epoch 137, Average discriminator loss : 0.5570139503367594, Average generator loss : 2.469743715268429
# epoch 138, Average discriminator loss : 0.5602395732269109, Average generator loss : 2.483867090439128
# epoch 139, Average discriminator loss : 0.5617173726313582, Average generator loss : 2.4842567310154995
# epoch 140, Average discriminator loss : 0.5612014674137686, Average generator loss : 2.472596444816233
# epoch 141, Average discriminator loss : 0.5562043777693098, Average generator loss : 2.5058382582441667
# epoch 142, Average discriminator loss : 0.5660082981965252, Average generator loss : 2.483570203602871
# epoch 143, Average discriminator loss : 0.5544780570769978, Average generator loss : 2.476190930214998
# epoch 144, Average discriminator loss : 0.5617886519877711, Average generator loss : 2.4570418518280315
# epoch 145, Average discriminator loss : 0.5596342922371125, Average generator loss : 2.4524139778636327
# epoch 146, Average discriminator loss : 0.557587325851494, Average generator loss : 2.491379283298956
# epoch 147, Average discriminator loss : 0.5504954114695576, Average generator loss : 2.5255643296464583
# epoch 148, Average discriminator loss : 0.5732014143021307, Average generator loss : 2.4336684908822317
# epoch 149, Average discriminator loss : 0.5453344162936523, Average generator loss : 2.5064570881495967
# epoch 150, Average discriminator loss : 0.559145014419734, Average generator loss : 2.484298636980146
# epoch 151, Average discriminator loss : 0.5849519422121137, Average generator loss : 2.4483118725714283
# epoch 152, Average discriminator loss : 0.5598591883605886, Average generator loss : 2.493947806759415
# epoch 153, Average discriminator loss : 0.5550010271161516, Average generator loss : 2.451088981093647
# epoch 154, Average discriminator loss : 0.5763255574992884, Average generator loss : 2.403827685062016
# epoch 155, Average discriminator loss : 0.563218748458078, Average generator loss : 2.4654198651001833
# epoch 156, Average discriminator loss : 0.5626044304014366, Average generator loss : 2.434521216098393
# epoch 157, Average discriminator loss : 0.5596734006828237, Average generator loss : 2.4473918531542624
# epoch 158, Average discriminator loss : 0.563527564300555, Average generator loss : 2.45206165982184
# epoch 159, Average discriminator loss : 0.5858447200784059, Average generator loss : 2.3882680540886994
# epoch 160, Average discriminator loss : 0.5519075117935645, Average generator loss : 2.4446224163625843
# epoch 161, Average discriminator loss : 0.5570498181280689, Average generator loss : 2.4422650069833916
# epoch 162, Average discriminator loss : 0.5841285811963483, Average generator loss : 2.4045513768062414
# epoch 163, Average discriminator loss : 0.5642809115837668, Average generator loss : 2.4302121478820515
# epoch 164, Average discriminator loss : 0.551467383019278, Average generator loss : 2.4570622867512926
# epoch 165, Average discriminator loss : 0.580969552291888, Average generator loss : 2.4062676763980186
# epoch 166, Average discriminator loss : 0.5808764537361181, Average generator loss : 2.4089409369174564
# epoch 167, Average discriminator loss : 0.5502966792784004, Average generator loss : 2.467724528268119
# epoch 168, Average discriminator loss : 0.5720074290984145, Average generator loss : 2.388389609684454
# epoch 169, Average discriminator loss : 0.5784084028172716, Average generator loss : 2.4167590141296387
# epoch 170, Average discriminator loss : 0.5691621609937365, Average generator loss : 2.3779107789012874
# epoch 171, Average discriminator loss : 0.5664063121113821, Average generator loss : 2.4322788225156127
# epoch 172, Average discriminator loss : 0.5703297547090833, Average generator loss : 2.415579624265154
# epoch 173, Average discriminator loss : 0.5810492030371015, Average generator loss : 2.373559539563188
# epoch 174, Average discriminator loss : 0.5796512131379029, Average generator loss : 2.4006688416561235
# epoch 175, Average discriminator loss : 0.5709210372416773, Average generator loss : 2.395015689814202
# epoch 176, Average discriminator loss : 0.5806169888683569, Average generator loss : 2.3943595797102026
# epoch 177, Average discriminator loss : 0.5515621421493102, Average generator loss : 2.471706671135448
# epoch 178, Average discriminator loss : 0.6172816987349609, Average generator loss : 2.2888386227260127
# epoch 179, Average discriminator loss : 0.5602028094162451, Average generator loss : 2.4105597255385924
# epoch 180, Average discriminator loss : 0.5705086772686967, Average generator loss : 2.4028958093340154
# epoch 181, Average discriminator loss : 0.5980060518344986, Average generator loss : 2.367269070349007
# epoch 182, Average discriminator loss : 0.5659347599911912, Average generator loss : 2.409963050735331
# epoch 183, Average discriminator loss : 0.5775943813479949, Average generator loss : 2.369533275889459
# epoch 184, Average discriminator loss : 0.5961114285148192, Average generator loss : 2.335538289257299
# epoch 185, Average discriminator loss : 0.5506677259908659, Average generator loss : 2.399259007979776
# epoch 186, Average discriminator loss : 0.5866614933882919, Average generator loss : 2.3506497178122263
# epoch 187, Average discriminator loss : 0.5796931940261448, Average generator loss : 2.384029027457549
# epoch 188, Average discriminator loss : 0.5716733439503429, Average generator loss : 2.3874444270802435
# epoch 189, Average discriminator loss : 0.5942579039903445, Average generator loss : 2.3291130689817052
# epoch 190, Average discriminator loss : 0.5722259347126862, Average generator loss : 2.3893975676777206
# epoch 191, Average discriminator loss : 0.5873531509782667, Average generator loss : 2.3577304042388345
# epoch 192, Average discriminator loss : 0.606984383034929, Average generator loss : 2.3172015698156625
# epoch 193, Average discriminator loss : 0.5610741744531649, Average generator loss : 2.394310937863644
# epoch 194, Average discriminator loss : 0.5803873739509939, Average generator loss : 2.3542869937754123
# epoch 195, Average discriminator loss : 0.5825710706064634, Average generator loss : 2.3410534167958197
# epoch 196, Average discriminator loss : 0.5921529278019878, Average generator loss : 2.3160352127574315
# epoch 197, Average discriminator loss : 0.5887071462435143, Average generator loss : 2.3525012542154187
# epoch 198, Average discriminator loss : 0.5850196230077298, Average generator loss : 2.3651199652769854
# epoch 199, Average discriminator loss : 0.5712973862607903, Average generator loss : 2.345572099507412
# epoch 200, Average discriminator loss : 0.6143601152384393, Average generator loss : 2.254540893519036
# epoch 201, Average discriminator loss : 0.5686432064693665, Average generator loss : 2.3162189153867345
# epoch 202, Average discriminator loss : 0.592714662585303, Average generator loss : 2.31477335680311
# epoch 203, Average discriminator loss : 0.59998203521577, Average generator loss : 2.323397304410132
# epoch 204, Average discriminator loss : 0.5786301457436285, Average generator loss : 2.3622940901283904
# epoch 205, Average discriminator loss : 0.585231903278939, Average generator loss : 2.329210796088816
# epoch 206, Average discriminator loss : 0.5841016674710211, Average generator loss : 2.311213401990516

# %%
def to_one_hat(x):
    out = np.zeros((len(x), 10))
    for i, a in enumerate(x):
        out[i, a] = 1
    return out

# %%
import matplotlib.pyplot as plt

z1 = np.random.normal(0, 1.0, [25, z_size])

x1_batch = [i for i in range(5,10)] * 5
x1_batch = to_one_hat(x1_batch)

fake = sess.run([fake_x], feed_dict={x1: x1_batch, z:z1})
fake = fake[0]
total_discriminator_loss += loss_batch

fig, axes = plt.subplots(5, 5, figsize = (10,10))
for i in range(25):
    im = fake[i, :]
    axes[i // 5, i % 5].imshow(im.reshape(28,28))
plt.show()

# %%
sess.close()
